# %% [markdown]
# # Dictionnaires
# Les dictionnaires sont des structures de controle **non-ordonnées**, c'est-a-dire que les valeurs qu'ils contiennent ne sont pas rangée selon un index, mais suivant une **clef unique**.
#
# Une utilisation parfaite des dictionnaires est pour regrouper ensemble des "variables" dans un meme conténaire. (ces variables ne sont pas de vraies variables, mais des **keys**).
#
# *On peut par exemple crée un dictionnaire inventaire qui regroupe plusieurs produits (les clefs) et leur quantités (les valeurs)*
#
# En **machine learning** et **deep learning**, les dictionnaires servent souvent à :
#
# * **Stocker et configurer des hyperparamètres** (par ex. `{"learning_rate": 0.01, "batch_size": 32}`), ce qui permet d’adapter facilement l’entraînement d’un modèle.
# * **Mapper des étiquettes** (ex. `{"chien": 0, "chat": 1}`) pour convertir des données textuelles en valeurs numériques exploitables par un algorithme.
# * **Sauvegarder les résultats** comme les métriques d’évaluation (`{"accuracy": 0.92, "loss": 0.08}`) pour suivre les performances d’un modèle.
#
# En résumé, ils agissent comme des *boîtes à données* flexibles pour tout ce qui doit être référencé rapidement par une clé, un rôle clé dans les pipelines ML/DL.
#
# # Création d’un dictionnaire : Synthase
#
# mon_dictionnaire = {
#
#     "clé1": valeur1,
#
#     "clé2": valeur2,
#
#     "clé3": valeur3
# }

# %%
inventaire = {'pommes': 100,
              'bananes': 80,
              'poires': 120}

# %%
inventaire.values()
# inventaire.values() retourne toutes les valeurs contenues dans un dictionnaire, sans les clés.
# Out:
# dict_values([100, 80, 120])

# %%
inventaire.keys()
# Renvoie toutes les clés du dictionnaire (sans les valeurs).
# Out:
# dict_keys(['pommes', 'bananes', 'poires'])

# %%
inventaire.items()
#  Renvoie clés + valeurs sous forme de paires (tuple)
# Out:
# dict_items([('pommes', 100), ('bananes', 80), ('poires', 120)])

# %%
# Utile pour : Boucler directement sur clé + valeur :

for fruit, quantite in inventaire.items():
    print(f"{fruit} : {quantite}")
# Out:
# pommes : 100
# bananes : 80
# poires : 120

# %%
len(inventaire)
# Out:
# 3

# %% [markdown]
# Voici comment ajouter une association key/value dans notre dictionnaire (attention si la clef existe déja elle est remplacée)

# %%
inventaire['abricots'] = 30
print(inventaire)
# Out:
# {'pommes': 100, 'bananes': 80, 'poires': 120, 'abricots': 30}

# %% [markdown]
# Attention : si vous cherchez une clef qui n'existe pas dans un dictionnaire, python vous retourne une erreur. Pour éviter cela, vous pouvez utiliser la méthode **get()**

# %%
inventaire.get('peches') # n'existe pas

# %%
inventaire.get('pommes') # pomme existe
# Out:
# 100

# %% [markdown]
# La méthode **pop()** permet de retirer une clef d'un dictionnaire tout en retournant la valeur associée a la clef.

# %%
abricots = inventaire.pop("abricots")
print(inventaire) # ne contient plus de clef abricots
print(abricots) # abricots contient la valeur du dictionnaire
# Out:
# {'pommes': 100, 'bananes': 80, 'poires': 120}
# 30

# %% [markdown]
# Pour utiliser une boucle for avec un dictionnaire, il est utile d'utiliser la méthode **items()** qui retourne a la fois les clefs et les valeurs

# %%
for key, value in inventaire.items():
  print(key, value)
# Out:
# pommes 100
# bananes 80
# poires 120

# %% [markdown]
# ### Quelques autres méthodes de dictionnaires à connaître
#
# 📌 **1. `dict.update()`** – Ajoute ou met à jour des éléments.
#
# ```python
# inventaire = {"pommes": 50, "bananes": 30}
# inventaire.update({"oranges": 20})
# print(inventaire)  # {'pommes': 50, 'bananes': 30, 'oranges': 20}
# ```
#
# 📌 **2. `dict.popitem()`** – Supprime et retourne le dernier élément ajouté.
#
# ```python
# print(inventaire.popitem())  # ('oranges', 20)
# ```
#
# 📌 **3. `dict.clear()`** – Vide complètement le dictionnaire.
#
# ```python
# inventaire.clear()
# print(inventaire)  # {}
# ```
#
# 📌 **4. `dict.copy()`** – Crée une copie indépendante.
#
# ```python
# copie_inv = inventaire.copy()
# ```
#
# 📌 **5. `dict.fromkeys()`** – Crée un dictionnaire avec des clés données et une même valeur.
#
# ```python
# fruits = dict.fromkeys(["pommes", "bananes"], 0)
# print(fruits)  # {'pommes': 0, 'bananes': 0}
# ```

# %% [markdown]
# ## 📝 Exercices pour débutants sur les dictionnaires en Python
#
# 1️⃣ **Création d’un dictionnaire**
# Crée un dictionnaire `etudiant` contenant :
#
# * Nom : "Amina"
# * Âge : 21
# * Filière : "Data Science"
#   Affiche le dictionnaire.
#
# ---
#
# 2️⃣ **Accéder à une valeur**
# À partir du dictionnaire suivant :
#
# ```python
# pays_capitales = {
#     "Togo": "Lomé",
#     "Bénin": "Porto-Novo",
#     "Sénégal": "Dakar"
# }
# ```
#
# Affiche la capitale du **Bénin**.
#
# ---
#
# 3️⃣ **Ajouter un élément**
#
# Ajoute la clé `"Mali"` avec la valeur `"Bamako"` au dictionnaire `pays_capitales`.
# Affiche le dictionnaire mis à jour.
#
# ---
#
# 4️⃣ **Modifier une valeur**
#
# Modifie l’âge de `etudiant` pour qu’il soit **22 ans**.
# Affiche le dictionnaire après modification.
#
# ---
#
# 5️⃣ **Boucler sur un dictionnaire**
#
# Avec le dictionnaire `pays_capitales`, affiche chaque pays suivi de sa capitale au format :
#
# ```
# La capitale du Togo est Lomé
# La capitale du Bénin est Porto-Novo
# ...
# ```

# %% [markdown]
# ## 📝 Exercices pour débutants sur les dictionnaires en Python (avec corrigés)
#
# ---
#
# ### 1️⃣ **Création d’un dictionnaire**
#
# **Énoncé :**
# Crée un dictionnaire `etudiant` contenant :
#
# * Nom : `"Amina"`
# * Âge : `21`
# * Filière : `"Data Science"`
#   Affiche le dictionnaire.
#
# **Correction :**
#
# ```python
# etudiant = {
#     "Nom": "Amina",
#     "Âge": 21,
#     "Filière": "Data Science"
# }
# print(etudiant)
# ```
#
# **Résultat attendu :**
#
# ```
# {'Nom': 'Amina', 'Âge': 21, 'Filière': 'Data Science'}
# ```
#
# ---
#
# ### 2️⃣ **Accéder à une valeur**
#
# **Énoncé :**
# À partir du dictionnaire suivant :
#
# ```python
# pays_capitales = {
#     "Togo": "Lomé",
#     "Bénin": "Porto-Novo",
#     "Sénégal": "Dakar"
# }
# ```
#
# Affiche la capitale du **Bénin**.
#
# **Correction :**
#
# ```python
# print(pays_capitales["Bénin"])
# ```
#
# **Résultat attendu :**
#
# ```
# Porto-Novo
# ```
#
# ---
#
# ### 3️⃣ **Ajouter un élément**
#
# **Énoncé :**
# Ajoute la clé `"Mali"` avec la valeur `"Bamako"` au dictionnaire `pays_capitales`.
# Affiche le dictionnaire mis à jour.
#
# **Correction :**
#
# ```python
# pays_capitales["Mali"] = "Bamako"
# print(pays_capitales)
# ```
#
# **Résultat attendu :**
#
# ```
# {'Togo': 'Lomé', 'Bénin': 'Porto-Novo', 'Sénégal': 'Dakar', 'Mali': 'Bamako'}
# ```
#
# ---
#
# ### 4️⃣ **Modifier une valeur**
#
# **Énoncé :**
# Modifie l’âge de `etudiant` pour qu’il soit **22 ans**.
# Affiche le dictionnaire après modification.
#
# **Correction :**
#
# ```python
# etudiant["Âge"] = 22
# print(etudiant)
# ```
#
# **Résultat attendu :**
#
# ```
# {'Nom': 'Amina', 'Âge': 22, 'Filière': 'Data Science'}
# ```
#
# ---
#
# ### 5️⃣ **Boucler sur un dictionnaire**
#
# **Énoncé :**
# Avec le dictionnaire `pays_capitales`, affiche chaque pays suivi de sa capitale au format :
#
# ```
# La capitale du Togo est Lomé
# La capitale du Bénin est Porto-Novo
# ...
# ```
#
# **Correction :**
#
# ```python
# for pays, capitale in pays_capitales.items():
#     print(f"La capitale du {pays} est {capitale}")
# ```
#
# **Résultat attendu :**
#
# ```
# La capitale du Togo est Lomé
# La capitale du Bénin est Porto-Novo
# La capitale du Sénégal est Dakar
# La capitale du Mali est Bamako
# ```

# %% [markdown]
# ## Autre Exercice et Solution
# Implémentez une fonction *trier(classeur, valeur)* qui place une valeur dans un dictionnaire en fonction de son signe

# %%
classeur = {'négatifs':[],
            'positifs':[]
            }

def trier(classeur, valeur):
  return classeur

# %%
# SOLUTION

def trier(classeur, valeur):
  if valeur >=0:
    classeur['positifs'].append(valeur)
  else:
    classeur['négatifs'].append(valeur)
  return classeur

# %%
trier(classeur, 9)
# Out:
# {'négatifs': [-2, -2, -4], 'positifs': [5, 9]}
